# %% [markdown]
# # Primeiro código

# %%
nome = 'joão'
idade = 30
texto = f" meu nome é {nome} e minha idade é {idade}"
texto
# Out:
# ' meu nome é joão e minha idade é 30'

# %% [markdown]
# # Carregando os dados

# %%
caminho_dados = "/content/drive/MyDrive/DRIVE/AD/2023_Viagem.csv"

# %%
import pandas as pd

df_viagens = pd.read_csv(caminho_dados, encoding="Windows-1252" , sep=";")
pd.set_option('display.max_columns', None)

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829852                           2023001618             Sem informaçã
# 829853                           2023001619             Sem informaçã
# 829854                           2023001628             Sem informaçã
# 829855                           2023001631             Sem informaçã
# 829856                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
df_viagens["Nome do órgão superior"]
# Out:
# 0         Ministério da Educação
# 1         Ministério da Educação
# 2         Ministério da Educação
# 3           Ministério da Defesa
# 4         Ministério da Educação
#                    ...
# 829852            Sem informação
# 829853            Sem informação
# 829854            Sem informação
# 829855            Sem informação
# 829856            Sem informação
# Name: Nome do órgão superior, Length: 829857, dtype: object

# %%
df_viagens['Valor diárias']
# Out:
# 0             0,00
# 1             0,00
# 2             0,00
# 3         39565,70
# 4          1013,96
#             ...
# 829852      606,89
# 829853     1089,00
# 829854      734,13
# 829855      319,28
# 829856        0,00
# Name: Valor diárias, Length: 829857, dtype: object

# %%
colunas = ["Nome do órgão superior",'Valor diárias']
df_viagens[colunas]
# Out:
#         Nome do órgão superior Valor diárias
# 0       Ministério da Educação          0,00
# 1       Ministério da Educação          0,00
# 2       Ministério da Educação          0,00
# 3         Ministério da Defesa      39565,70
# 4       Ministério da Educação       1013,96
# ...                        ...           ...
# 829852          Sem informação        606,89
# 829853          Sem informação       1089,00
# 829854          Sem informação        734,13
# 829855          Sem informação        319,28
# 829856          Sem informação          0,00
#
# [829857 rows x 2 columns]

# %%
df_viagens["Nome do órgão superior"].str.upper().str.replace("MINISTÉRIO", "MIN.")
# Out:
# 0         MIN. DA EDUCAÇÃO
# 1         MIN. DA EDUCAÇÃO
# 2         MIN. DA EDUCAÇÃO
# 3           MIN. DA DEFESA
# 4         MIN. DA EDUCAÇÃO
#                 ...
# 829852      SEM INFORMAÇÃO
# 829853      SEM INFORMAÇÃO
# 829854      SEM INFORMAÇÃO
# 829855      SEM INFORMAÇÃO
# 829856      SEM INFORMAÇÃO
# Name: Nome do órgão superior, Length: 829857, dtype: object

# %%
df_viagens[["Valor diárias", "Valor passagens"]]
# Out:
#        Valor diárias Valor passagens
# 0               0,00            0,00
# 1               0,00         7894,50
# 2               0,00            0,00
# 3           39565,70         7434,13
# 4            1013,96            0,00
# ...              ...             ...
# 829852        606,89         3331,29
# 829853       1089,00         1837,18
# 829854        734,13         4555,95
# 829855        319,28         3745,53
# 829856          0,00         2961,55
#
# [829857 rows x 2 columns]

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829857 entries, 0 to 829856
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  829857 non-null  int64
#  1   Número da Proposta (PCDP)            829857 non-null  object
#  2   Situação                             829857 non-null  object
#  3   Viagem Urgente                       829857 non-null  object
#  4   Justificativa Urgência Viagem        829755 non-null  object
#  5   Código do órgão superior             829857 non-null  int64
#  6   Nome do órgão superior               829857 non-null  object
#  7   Código órgão solicitante             829857 non-null  int64
#  8   Nome órgão solicitante               829857 non-null  object
#  9   CPF viajante                         749648 non-null  object
#  10  Nome                                 829857 non-null  object
# ...

# %%
df_viagens["Valor diárias"] = df_viagens["Valor diárias"].str.replace("," , ".").astype(float)
df_viagens["Valor diárias"]
# Out:
# 0            0.00
# 1            0.00
# 2            0.00
# 3        39565.70
# 4         1013.96
#            ...
# 829852     606.89
# 829853    1089.00
# 829854     734.13
# 829855     319.28
# 829856       0.00
# Name: Valor diárias, Length: 829857, dtype: float64

# %%
df_viagens["Valor outros gastos"] = df_viagens["Valor outros gastos"].str.replace("," , ".").astype(float)
df_viagens["Valor passagens"] = df_viagens["Valor passagens"].str.replace("," , ".").astype(float)
df_viagens["Valor devolução"] = df_viagens["Valor devolução"].str.replace("," , ".").astype(float)

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829857 entries, 0 to 829856
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  829857 non-null  int64
#  1   Número da Proposta (PCDP)            829857 non-null  object
#  2   Situação                             829857 non-null  object
#  3   Viagem Urgente                       829857 non-null  object
#  4   Justificativa Urgência Viagem        829755 non-null  object
#  5   Código do órgão superior             829857 non-null  int64
#  6   Nome do órgão superior               829857 non-null  object
#  7   Código órgão solicitante             829857 non-null  int64
#  8   Nome órgão solicitante               829857 non-null  object
#  9   CPF viajante                         749648 non-null  object
#  10  Nome                                 829857 non-null  object
# ...

# %%
df_viagens["Valor diárias"] + df_viagens["Valor passagens"]
# Out:
# 0            0.00
# 1         7894.50
# 2            0.00
# 3        46999.83
# 4         1013.96
#            ...
# 829852    3938.18
# 829853    2926.18
# 829854    5290.08
# 829855    4064.81
# 829856    2961.55
# Length: 829857, dtype: float64

# %%
df_viagens["Valor diárias"] * 3
# Out:
# 0             0.00
# 1             0.00
# 2             0.00
# 3        118697.10
# 4          3041.88
#             ...
# 829852     1820.67
# 829853     3267.00
# 829854     2202.39
# 829855      957.84
# 829856        0.00
# Name: Valor diárias, Length: 829857, dtype: float64

# %%
df_viagens['Despesas'] = df_viagens["Valor diárias"] + df_viagens["Valor passagens"] + df_viagens["Valor outros gastos"]
df_viagens['Despesas']
# Out:
# 0            0.00
# 1         7894.50
# 2            0.00
# 3        48095.18
# 4         1013.96
#            ...
# 829852    3938.18
# 829853    2926.18
# 829854    5290.08
# 829855    4464.81
# 829856    2961.55
# Name: Despesas, Length: 829857, dtype: float64

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829852                           2023001618             Sem informaçã
# 829853                           2023001619             Sem informaçã
# 829854                           2023001628             Sem informaçã
# 829855                           2023001631             Sem informaçã
# 829856                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
(df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporção de viagens').reset_index()
# Out:
#                                      Cargo  Proporção de viagens
# 0        Informações protegidas por sigilo                 23.39
# 1         PROFESSOR DO MAGISTERIO SUPERIOR                 10.82
# 2    PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.43
# 3              CONTRATADO LEI 8745/93 - NI                  3.51
# 4      AUDITOR FISCAL FEDERAL AGROPECUARIO                  3.28
# ..                                     ...                   ...
# 818              TECNICO EM HIGIENE DENTAL                  0.00
# 819            OPERADOR DE TELE IMPRESSORA                  0.00
# 820  ASSISTENTE TECNICO EM DESENV REGIONAL                  0.00
# 821                  TECNICO DE MANUTENCAO                  0.00
# 822                               VIDREIRO                  0.00
#
# [823 rows x 2 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

df_viagens.groupby('Cargo')['Despesas'].sum().reset_index().sort_values(by='Despesas', ascending=False)
# Out:
#                                         Cargo     Despesas
# 444         Informações protegidas por sigilo 374188816.46
# 569          PROFESSOR DO MAGISTERIO SUPERIOR 111307060.47
# 570     PROFESSOR ENS BASICO TECN TECNOLOGICO  52769327.23
# 687                  TECNICO DO SEGURO SOCIAL  45980663.32
# 72                         ANALISTA AMBIENTAL  35371056.07
# ..                                        ...          ...
# 725                       TECNICO EM GEOLOGIA         0.00
# 819                                  VIDREIRO         0.00
# 735                     TECNICO EM METALURGIA         0.00
# 302                               CENOTECNICO         0.00
# 152  ASG - OPERADOR DE MAQUINA E EQUIPAMENTOS         0.00
#
# [823 rows x 2 columns]

# %%
viagens_por_cargo = (df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporção de viagens').reset_index()

# %%
filtro_mais_de_1_pct = viagens_por_cargo['Proporção de viagens'] > 1

# %%
viagens_por_cargo
# Out:
#                                      Cargo  Proporção de viagens
# 0        Informações protegidas por sigilo                 23.39
# 1         PROFESSOR DO MAGISTERIO SUPERIOR                 10.82
# 2    PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.43
# 3              CONTRATADO LEI 8745/93 - NI                  3.51
# 4      AUDITOR FISCAL FEDERAL AGROPECUARIO                  3.28
# ..                                     ...                   ...
# 818              TECNICO EM HIGIENE DENTAL                  0.00
# 819            OPERADOR DE TELE IMPRESSORA                  0.00
# 820  ASSISTENTE TECNICO EM DESENV REGIONAL                  0.00
# 821                  TECNICO DE MANUTENCAO                  0.00
# 822                               VIDREIRO                  0.00
#
# [823 rows x 2 columns]

# %%
viagens_por_cargo[filtro_mais_de_1_pct]
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 23.39
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                 10.82
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.43
# 3                CONTRATADO LEI 8745/93 - NI                  3.51
# 4        AUDITOR FISCAL FEDERAL AGROPECUARIO                  3.28
# 5                         ANALISTA AMBIENTAL                  2.69
# 6                ASSISTENTE EM ADMINISTRAçãO                  2.31
# 7    TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  2.14
# 8                   TECNICO DO SEGURO SOCIAL                  2.11
# 9   AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL                  1.99
# 10    ANALISTA TRIBUTARIO REC FEDERAL BRASIL                  1.68
# 11                AUDITOR FISCAL DO TRABALHO                  1.53
# 12                                 MOTORISTA                  1.51
# ...

# %%
filtro_eh_tecnico =  viagens_por_cargo['Cargo'].str.startswith('TECNICO')

# %%
viagens_por_cargo[filtro_eh_tecnico]
# Out:
#                                        Cargo  Proporção de viagens
# 7    TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  2.14
# 8                   TECNICO DO SEGURO SOCIAL                  2.11
# 14                         TECNICO AMBIENTAL                  1.18
# 18                    TECNICO ADMINISTRATIVO                  0.87
# 23          TECNICO EM ASSUNTOS EDUCACIONAIS                  0.57
# ..                                       ...                   ...
# 801                  TECNICO ESP SERV ECONOM                  0.00
# 804             TECNICO NM - 02 (DEC JUD-ME)                  0.00
# 815                    TECNICO EM MANUTENCAO                  0.00
# 818                TECNICO EM HIGIENE DENTAL                  0.00
# 821                    TECNICO DE MANUTENCAO                  0.00
#
# [142 rows x 2 columns]

# %%
viagens_por_cargo[filtro_eh_tecnico & filtro_mais_de_1_pct]
# Out:
#                                       Cargo  Proporção de viagens
# 7   TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  2.14
# 8                  TECNICO DO SEGURO SOCIAL                  2.11
# 14                        TECNICO AMBIENTAL                  1.18

# %%
# Despesas Por Cargo
gastos_totais_por_cargo = df_viagens.groupby('Cargo')['Despesas'].sum().reset_index()

# %%
# Gastos > 10.000.000
gastos_totais_por_cargo[gastos_totais_por_cargo['Despesas'] > 10_000_000]
# Out:
#                                         Cargo     Despesas
# 15                      AGENTE ADMINISTRATIVO  15023006.31
# 72                         ANALISTA AMBIENTAL  35371056.07
# 95                  ANALISTA DO SEGURO SOCIAL  15990188.61
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL  14875855.38
# 179               ASSISTENTE EM ADMINISTRAçãO  15151518.48
# 208                AUDITOR FISCAL DO TRABALHO  10376688.67
# 209       AUDITOR FISCAL FEDERAL AGROPECUARIO  24315111.98
# 210  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL  24406804.29
# 316               CONTRATADO LEI 8745/93 - NI  17510463.07
# 386     ESP EM REG DE SERV PUB DE TELECOMUNIC  10037621.59
# 387         ESP EM REGULACAO DE AVIACAO CIVIL  12716538.17
# 390   ESP EM REGULACAO E VIGILANCIA SANITARIA  24451002.94
# 444         Informações protegidas por sigilo 374188816.46
# 481               MINISTRO DE PRIMEIRA CLASSE  15873238.49
# 553                       PRIMEIRO SECRETARIO  13036267.32
# ...

# %%
# Gasto médio Por Cargo
gasto_medio_por_cargo = df_viagens.groupby('Cargo')['Despesas'].mean().reset_index()
gasto_medio_por_cargo
# Out:
#                                     Cargo  Despesas
# 0           AAD-AUX DE RECURSOS MATERIAIS   3592.10
# 1             AAD-AUXILIAR ADMINISTRATIVO    115.76
# 2               AAD-AUXILIAR DE OPERACOES   7973.39
# 3    AAD-AUXILIAR DE RECURSOS FINANCEIROS  15545.94
# 4         AAD-OPERADOR DE MICROCOMPUTADOR   1186.47
# ..                                    ...       ...
# 818          VICE-PRESIDENTE DA REPUBLICA   7068.20
# 819                              VIDREIRO      0.00
# 820                             VIGILANTE    693.31
# 821                   VISITADOR SANITARIO   1402.57
# 822                           ZOOTECNISTA    655.56
#
# [823 rows x 2 columns]

# %%
# Gasto médio > 10.000
gasto_medio_por_cargo[gasto_medio_por_cargo['Despesas'] > 10_000]
# Out:
#                                        Cargo  Despesas
# 3       AAD-AUXILIAR DE RECURSOS FINANCEIROS  15545.94
# 37          AGENTE DE SERVICOS COMPLEMETARES  13975.38
# 170                ASSISTENTE DE CHANCELARIA  10360.63
# 231                AUXILIAR DE CONTABILIDADE  14015.48
# 258            AUXILIAR DE SERVICOS DIVERSOS  19000.96
# 269            AUXILIAR NM - 06 (DEC JUD-ME)  12323.94
# 306                              CONSELHEIRO  12271.83
# 326    DELEGADO DE POLICIA - PRIMEIRA CLASSE  34105.32
# 390  ESP EM REGULACAO E VIGILANCIA SANITARIA  13005.85
# 403        ESPECIALISTA EM ATIV HOSPITALARES  12686.31
# 472              MEDICO PROGRAMA MAIS MEDICO  11367.61
# 481              MINISTRO DE PRIMEIRA CLASSE  19032.66
# 482               MINISTRO DE SEGUNDA CLASSE  14535.49
# 499                   OFICIAL DE CHANCELARIA  11375.51
# 525   PAPILOSCOPISTA POLICIAL-SEGUNDA CLASSE  15421.69
# 552                        PRIMEIRO SARGENTO  17509.58
# ...

# %%
# Valores Nulos                 dropna=False Não excluir nulo
df_viagens['Cargo'].value_counts(dropna=False)
# Out:
# Cargo
# NaN                                      323589
# Informações protegidas por sigilo        118399
# PROFESSOR DO MAGISTERIO SUPERIOR          54797
# PROFESSOR ENS BASICO TECN TECNOLOGICO     37612
# CONTRATADO LEI 8745/93 - NI               17787
#                                           ...
# TECNICO EM HIGIENE DENTAL                     1
# OPERADOR DE TELE IMPRESSORA                   1
# ASSISTENTE TECNICO EM DESENV REGIONAL         1
# TECNICO DE MANUTENCAO                         1
# VIDREIRO                                      1
# Name: count, Length: 824, dtype: int64

# %%
# Apagando valores nulos da coluna cargo
df_viagens.dropna(subset='Cargo')
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 2                                  18236583                 000018/23
# 4                                  18296348                 000070/23
# 6                                  18303291             Informações p
# 14                                 18350498             Informações p
# ...                                     ...                       ...
# 829852                           2023001618             Sem informaçã
# 829853                           2023001619             Sem informaçã
# 829854                           2023001628             Sem informaçã
# 829855                           2023001631             Sem informaçã
# 829856                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 2       Realizada            NÃO
# ...

# %%
# Preenchendo valores nulos
# df_viagens.fillna('NÃO IDENTIFICADO')
df_viagens['Cargo'] = df_viagens['Cargo'].fillna('NÃO IDENTIFICADO')
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829852                           2023001618             Sem informaçã
# 829853                           2023001619             Sem informaçã
# 829854                           2023001628             Sem informaçã
# 829855                           2023001631             Sem informaçã
# 829856                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
df_viagens[["Período - Data de início", "Período - Data de fim"]]
# Out:
#        Período - Data de início Período - Data de fim
# 0                    01/01/2023            02/12/2023
# 1                    25/02/2023            06/03/2023
# 2                    16/01/2023            28/02/2024
# 3                    10/01/2023            29/01/2023
# 4                    05/02/2023            10/02/2023
# ...                         ...                   ...
# 829852               05/12/2023            06/12/2023
# 829853               11/12/2023            13/12/2023
# 829854               07/12/2023            08/12/2023
# 829855               11/12/2023            11/12/2023
# 829856               15/12/2023            18/12/2023
#
# [829857 rows x 2 columns]

# %%
df_viagens["Período - Data de início"]
# Out:
# 0         01/01/2023
# 1         25/02/2023
# 2         16/01/2023
# 3         10/01/2023
# 4         05/02/2023
#              ...
# 829852    05/12/2023
# 829853    11/12/2023
# 829854    07/12/2023
# 829855    11/12/2023
# 829856    15/12/2023
# Name: Período - Data de início, Length: 829857, dtype: object

# %%
# Transformando para o tipo DATA
pd.to_datetime(df_viagens["Período - Data de início"], format="%d/%m/%Y")
# Out:
# 0        2023-01-01
# 1        2023-02-25
# 2        2023-01-16
# 3        2023-01-10
# 4        2023-02-05
#             ...
# 829852   2023-12-05
# 829853   2023-12-11
# 829854   2023-12-07
# 829855   2023-12-11
# 829856   2023-12-15
# Name: Período - Data de início, Length: 829857, dtype: datetime64[ns]

# %%
# Transformando as colunas da tabela Original
df_viagens["Período - Data de início"] = pd.to_datetime(df_viagens["Período - Data de início"], format="%d/%m/%Y")
df_viagens["Período - Data de fim"] = pd.to_datetime(df_viagens["Período - Data de fim"], format="%d/%m/%Y")

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829852                           2023001618             Sem informaçã
# 829853                           2023001619             Sem informaçã
# 829854                           2023001628             Sem informaçã
# 829855                           2023001631             Sem informaçã
# 829856                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
# nome do mês da viagem
df_viagens['Mês da viagem'] = df_viagens['Período - Data de início'].dt.month_name()

# %%
df_viagens['Dias de viagem'] = (df_viagens['Período - Data de fim'] - df_viagens['Período - Data de início']).dt.days

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829852                           2023001618             Sem informaçã
# 829853                           2023001619             Sem informaçã
# 829854                           2023001628             Sem informaçã
# 829855                           2023001631             Sem informaçã
# 829856                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
# USANDO O .agg() PARA CRIAR COLONUNAS AGRUPADAS POR CARGO

(
    df_viagens.
    groupby('Cargo')
    .agg(
        despesa_media=('Despesas', 'mean'),
        duracao_media=('Dias de viagem', 'mean'),
        despesas_totais=('Despesas', 'sum'),
        destino_mais_frequente=('Destinos', pd.Series.mode),
        n_viagens=('Nome', 'count')
    )
    .reset_index()

 )
# Out:
#                                     Cargo  despesa_media  duracao_media  \
# 0           AAD-AUX DE RECURSOS MATERIAIS        3592.10           9.40
# 1             AAD-AUXILIAR ADMINISTRATIVO         115.76           0.00
# 2               AAD-AUXILIAR DE OPERACOES        7973.39          16.71
# 3    AAD-AUXILIAR DE RECURSOS FINANCEIROS       15545.94           5.50
# 4         AAD-OPERADOR DE MICROCOMPUTADOR        1186.47           4.00
# ..                                    ...            ...            ...
# 819          VICE-PRESIDENTE DA REPUBLICA        7068.20           1.50
# 820                              VIDREIRO           0.00           6.00
# 821                             VIGILANTE         693.31           1.79
# 822                   VISITADOR SANITARIO        1402.57           3.88
# 823                           ZOOTECNISTA         655.56           1.87
#
#      despesas_totais             destino_mais_frequente  n_viagens
# ...

# %%
# transformando em proporção, do total de viagens por cargo
df_cargos =  df_viagens['Cargo'].value_counts(normalize=True).reset_index()
df_cargos
# Out:
#                                      Cargo  proportion
# 0                         NÃO IDENTIFICADO        0.39
# 1        Informações protegidas por sigilo        0.14
# 2         PROFESSOR DO MAGISTERIO SUPERIOR        0.07
# 3    PROFESSOR ENS BASICO TECN TECNOLOGICO        0.05
# 4              CONTRATADO LEI 8745/93 - NI        0.02
# ..                                     ...         ...
# 819              TECNICO EM HIGIENE DENTAL        0.00
# 820            OPERADOR DE TELE IMPRESSORA        0.00
# 821  ASSISTENTE TECNICO EM DESENV REGIONAL        0.00
# 822                  TECNICO DE MANUTENCAO        0.00
# 823                               VIDREIRO        0.00
#
# [824 rows x 2 columns]

# %%
# cargos com mais de 1% do total de viagens
df_cargos.loc[df_cargos['proportion'] > 0.01, 'Cargo']
# Out:
# 0                             NÃO IDENTIFICADO
# 1            Informações protegidas por sigilo
# 2             PROFESSOR DO MAGISTERIO SUPERIOR
# 3        PROFESSOR ENS BASICO TECN TECNOLOGICO
# 4                  CONTRATADO LEI 8745/93 - NI
# 5          AUDITOR FISCAL FEDERAL AGROPECUARIO
# 6                           ANALISTA AMBIENTAL
# 7                  ASSISTENTE EM ADMINISTRAçãO
# 8      TECNICO INFOR GEOGRAFICAS E ESTATISTICA
# 9                     TECNICO DO SEGURO SOCIAL
# 10    AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL
# 11      ANALISTA TRIBUTARIO REC FEDERAL BRASIL
# Name: Cargo, dtype: object

# %%
df_viagens_consolidado =  (
    df_viagens.
    groupby('Cargo')
    .agg(
        despesa_media=('Despesas', 'mean'),
        duracao_media=('Dias de viagem', 'mean'),
        despesas_totais=('Despesas', 'sum'),
        destino_mais_frequente=('Destinos', pd.Series.mode),
        n_viagens=('Nome', 'count')
    )
    .reset_index()

 )

# %%
# cargos com mais de 1% do total de viagens
cargos_relevantes = df_cargos.loc[df_cargos['proportion'] > 0.01, 'Cargo']

# %%
# existe cargos_relevantes na coluna cargo do df_viagens_consolidado
filtro = df_viagens_consolidado['Cargo'].isin(cargos_relevantes)

# %%
# AS LINHAS DA TABELA df_viagens_consolidado QUE CONTÉM OS CARGOS COM MAIS DE 1% DO TOTAL DE VIAGENS
df_final = df_viagens_consolidado[filtro].sort_values(by='n_viagens', ascending=False)

# %%
df_final
# Out:
#                                         Cargo  despesa_media  duracao_media  \
# 495                          NÃO IDENTIFICADO        3259.77           8.02
# 444         Informações protegidas por sigilo        3160.41           7.49
# 570          PROFESSOR DO MAGISTERIO SUPERIOR        2031.26           4.17
# 571     PROFESSOR ENS BASICO TECN TECNOLOGICO        1402.99           2.39
# 316               CONTRATADO LEI 8745/93 - NI         984.45           2.84
# 209       AUDITOR FISCAL FEDERAL AGROPECUARIO        1466.18           2.06
# 72                         ANALISTA AMBIENTAL        2596.04           5.13
# 179               ASSISTENTE EM ADMINISTRAçãO        1292.90           2.24
# 778   TECNICO INFOR GEOGRAFICAS E ESTATISTICA        1457.08           3.19
# 688                  TECNICO DO SEGURO SOCIAL        4306.11          11.38
# 210  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL        2417.95           2.84
# ...

# %%
df_final.plot.bar(x='Cargo', y='n_viagens')
# Out:
# <Axes: xlabel='Cargo'>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.barh(df_final['Cargo'], df_final['n_viagens'], color="#49deac")
ax.invert_yaxis() # inverte o eixo Y do maior para o menor
ax.set_facecolor('#3b3b47') # plano de fundo

fig.suptitle('Viagens por Cargo Público (2023)') # titulo do gráfico

plt.figtext(0.65, 0.89, 'Fonte: Portal da Transparência', fontsize=8) # titulo da figura

plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8) # tamanho do eixo Y

plt.xlabel('Número de viagens')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.barh(df_final['Cargo'], df_final['despesa_media'], color="#49deac")
ax.invert_yaxis() # inverte o eixo Y do maior para o menor
ax.set_facecolor('#3b3b47') # plano de fundo

fig.suptitle('Despesa média em Viagens por Cargo Público (2023)') # titulo do gráfico

plt.figtext(0.65, 0.89, 'Fonte: Portal da Transparência', fontsize=8) # titulo da figura

plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8) # tamanho do eixo Y

plt.xlabel('Despesa média')

plt.show()

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829852                           2023001618             Sem informaçã
# 829853                           2023001619             Sem informaçã
# 829854                           2023001628             Sem informaçã
# 829855                           2023001631             Sem informaçã
# 829856                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.scatter(df_viagens['Dias de viagem'], df_viagens['Despesas'], alpha=0.2) # alpha=0.2 para ver a concentração dos dados
# ax.set_xlim(0, 100)
# ax.set_ylim(0, 25_000)

# %%
(df_viagens['Despesas'] > 175_000).value_counts()
# Out:
# Despesas
# False    829852
# True          5
# Name: count, dtype: int64

# %%
filtro = df_viagens['Despesas'] > 175_000

# %%
df_viagens[filtro]
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 23527                              18654059             Informações p
# 129236                             18782567              000277/23-5C
# 129286                             18782625              000289/23-5C
# 207393                             18877982             Informações p
# 467624                             19194886                 004304/23
#
#          Situação Viagem Urgente  \
# 23527   Realizada            NÃO
# 129236  Realizada            SIM
# 129286  Realizada            SIM
# 207393  Realizada            NÃO
# 467624  Realizada            SIM
#
#                             Justificativa Urgência Viagem  \
# 23527   Informação protegida por sigilo nos termos da ...
# 129236  A autorização de afastamento foi publicada hoj...
# 129286  Devido ao cancelamento da Visita Oficial do PR...
# 207393  Informação protegida por sigilo nos termos da ...
# ...

# %%
caminho_dados_passagens = "/content/drive/MyDrive/DRIVE/AD/2023_Passagem.csv"

df_passagens = pd.read_csv(caminho_dados_passagens, encoding="Windows-1252" , sep=";", decimal=",")
pd.set_option('display.max_columns', None)

df_passagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18159396                 000001/23
# 1                                  18159396                 000001/23
# 2                                  18288418              000007/23-1C
# 3                                  18302983                 000001/23
# 4                                  18306758                 000002/23
# ...                                     ...                       ...
# 389317                           2023001628             Sem informaçã
# 389318                           2023001628             Sem informaçã
# 389319                           2023001631             Sem informaçã
# 389320                           2023001631             Sem informaçã
# 389321                           2023001651             Sem informaçã
#
#        Meio de transporte País - Origem ida   UF - Origem ida  \
# 0                   Aéreo            Brasil    Rio de Janeiro
# ...

# %%
df_passagens[df_passagens['Identificador do processo de viagem'] ==19194886]
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 232792                             19194886                 004304/23
# 232793                             19194886                 004304/23
# 232794                             19194886                 004304/23
# 232795                             19194886                 004304/23
# 232796                             19194886                 004304/23
# 232797                             19194886                 004304/23
# 232798                             19194886                 004304/23
#
#        Meio de transporte          País - Origem ida UF - Origem ida  \
# 232792              Aéreo                  Filipinas             NaN
# 232793              Aéreo                     Brasil       São Paulo
# 232794              Aéreo                  Indonésia             NaN
# 232795              Aéreo  Estados Unidos da América             NaN
# ...

# %%
df_viagens.merge(df_passagens)
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18159396                 000001/23
# 1                                  18159396                 000001/23
# 2                                  18288418              000007/23-1C
# 3                                  18302983                 000001/23
# 4                                  18306758                 000002/23
# ...                                     ...                       ...
# 389325                           2023001628             Sem informaçã
# 389326                           2023001628             Sem informaçã
# 389327                           2023001631             Sem informaçã
# 389328                           2023001631             Sem informaçã
# 389329                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
caminho_saida = "/content/drive/MyDrive/DRIVE/AD/output/tabela.xlsx"

# %%
caminho_saida_csv = "/content/drive/MyDrive/DRIVE/AD/output/tabela.csv"

# %%
df_final.to_excel(caminho_saida, index=False) # oculta o index

# %%
df_final.to_csv(caminho_saida_csv, index=False) # oculta o index

# %%
import matplotlib.pyplot as plt

caminho_figura = "/content/drive/MyDrive/DRIVE/AD/output/figura.png"

# Criando a figura
fig, ax = plt.subplots(figsize=(16, 6))

# Plotando o gráfico
ax.barh(df_final['Cargo'], df_final['n_viagens'], color="#49deac")
ax.invert_yaxis() # inverte o eixo Y do maior para o menor

# Ajustando o gráfico
ax.set_facecolor('#3b3b47') # plano de fundo
fig.suptitle('Viagens por Cargo Público (2023)') # titulo do gráfico
plt.figtext(0.65, 0.89, 'Fonte: Portal da Transparência', fontsize=8) # titulo da figura
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8) # tamanho do eixo Y
plt.xlabel('Número de viagens')


# Salvando o gráfico
plt.savefig(caminho_figura, bbox_inches='tight')
